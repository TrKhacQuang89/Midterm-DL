# %%
def initialize_model():
    # init model
    return model

def dataset(path):
    # load dataset from storage
    return dataset

def forward(image, model):
    return output

def loss(output, expect):
    # calculate loss for model output and expected result
    return loss

def backward(loss, model):
    return gradient

def udpate_parameter(gradient, model):
    # update model
    return updated_model

def train(model):
    dataset = dataset("lmao")
    epochs = 10
    best_loss = inf
    for i in range(epochs):
        total_loss
        for image, label in dataset:
            output = forward(image)
            loss = loss(output, label)
            total_loss += loss
            gradient = backward(loss, model)
            model = udpate_parameter(gradient, model)
        if total_loss < best_loss:
            save(model)
    
    return model

def test(model):
    test_dataset = dataset("test lmao")
    total_loss = 0
    for image, lable in test_dataset:
        output = forward(image)
        loss = loss(output, label)
        # total_loss += loss
        total_loss = total_loss + loss

    average_loss = total_loss / len(dataset) 


def main():
    model = initialize_model()
    model = train(model)
    average_loss = test(model)
    print(f"average loss: {average_loss}")
